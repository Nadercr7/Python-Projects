# %% [markdown]
# # **PyGWalker Cheat Sheet By Nader NOV 2024**
# **Interactive Data Analysis and Visualization Simplified**

# %% [markdown]
# ![Screenshot 2024-11-19 124453.png](attachment:c17f52de-b71b-4441-8306-27b663763e32.png)

# %% [markdown]
# ## **About Me**
#
# I'm **Nader**. I am a passionate **Artificial Intelligence (AI) student** currently studying at **Kafrelsheikh University**. I have a strong interest in **AI**, **machine learning**, **competitive programming**, and exploring the vast world of technology. My journey into the field of programming started with learning `C++`, and I have since expanded my skills into `Python` and `Object-Oriented Programming (OOP)`.
#
# ###### You can find me here : [Nader Mohamed](https://linktr.ee/nader__7)
#
# ---
#
# ## **About This Cheat Sheet**
# Welcome to the PyGWalker Cheat Sheet! As a data enthusiast and Python practitioner, this guide will help you harness the power of PyGWalker for interactive data exploration and visualization. Whether you're an aspiring data analyst or an experienced professional, this cheat sheet is your go-to reference for using PyGWalker effectively.
#
# ---
#
# ## **What Makes This Cheat Sheet Special?**
# - **Practical Focus**: Examples derived from real-world data visualization tasks.
# - **Copy-Paste Ready**: Every code snippet is ready to use in Jupyter Notebooks.
# - **Interactive Exploration**: Introduces tools to turn static data into dynamic insights.
# - **Progressive Learning**: Starts with basics, progresses to advanced features.
# - **Optimized Workflow**: Tips for improving user experience with large datasets.
#
# ---
#
# ## **What You’ll Learn**
# 1. **Installation and Setup**: Get PyGWalker up and running quickly.
# 2. **Data Loading**: Import and prepare data for visualization.
# 3. **Interactive Features**: Explore how to interact with your data.
# 4. **Customization Options**: Learn about themes, configurations, and exporting results.
# 5. **Best Practices**: Tips for maximizing PyGWalker’s potential.
#
# ---
#
# ## **Why PyGWalker?**
# PyGWalker empowers you to:
# - Create Tableau-like interactive visualizations with minimal effort.
# - Turn pandas DataFrames into a user-friendly graphical interface.
# - Perform exploratory data analysis (EDA) interactively without complex code.
# - Collaborate and share insights with exportable results.
#
# **Prerequisites**:
# - Basic Python knowledge.
# - Jupyter Notebook installed.
# - PyGWalker library installed (`pip install pygwalker`).
#
# ---
#
# ## **Getting Started**
#
# ### **1. Installation**
# Install PyGWalker via pip:

# %%
pip install pygwalker
# Out:
# Requirement already satisfied: pygwalker in c:\users\ehabh\anaconda3\lib\site-packages (0.4.9.13)
# Requirement already satisfied: anywidget in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (0.9.13)
# Requirement already satisfied: appdirs in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.4.4)
# Requirement already satisfied: arrow in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.2.3)
# Requirement already satisfied: astor in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (0.8.1)
# Requirement already satisfied: cachetools in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (5.3.3)
# Requirement already satisfied: duckdb<2.0.0,>=0.10.1 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.1.3)
# Requirement already satisfied: gw-dsl-parser==0.1.49.1 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (0.1.49.1)
# Requirement already satisfied: ipylab<=1.0.0 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.0.0)
# Requirement already satisfied: ipython in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from pygwalker) (8.24.0)
# Requirement already satisfied: ipywidgets in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (8.1.5)
# Requirement already satisfied: jinja2 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (3.1.4)
# Requirement already satisfied: kanaries-track==0.0.5 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (0.0.5)
# Requirement already satisfied: numpy<2.0.0 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.26.4)
# Requirement already satisfied: packaging in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (23.2)
# Requirement already satisfied: pandas in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2.2.3)
# Requirement already satisfied: psutil in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from pygwalker) (5.9.8)
# Requirement already satisfied: pyarrow in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (14.0.2)
# Requirement already satisfied: pydantic in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2.5.3)
# Requirement already satisfied: pytz in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2024.1)
# Requirement already satisfied: quickjs in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (1.19.4)
# Requirement already satisfied: requests in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2.32.2)
# Requirement already satisfied: segment-analytics-python==2.2.3 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (2.0.30)
# Requirement already satisfied: sqlglot>=23.15.8 in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (25.31.4)
# Requirement already satisfied: traitlets in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from pygwalker) (5.14.3)
# Requirement already satisfied: typing-extensions in c:\users\ehabh\anaconda3\lib\site-packages (from pygwalker) (4.11.0)
# Requirement already satisfied: wasmtime>=12.0.0 in c:\users\ehabh\anaconda3\lib\site-packages (from gw-dsl-parser==0.1.49.1->pygwalker) (25.0.0)
# Requirement already satisfied: backoff>=2.2.1 in c:\users\ehabh\anaconda3\lib\site-packages (from kanaries-track==0.0.5->pygwalker) (2.2.1)
# Requirement already satisfied: dateutils>=0.6.12 in c:\users\ehabh\anaconda3\lib\site-packages (from kanaries-track==0.0.5->pygwalker) (0.6.12)
# Requirement already satisfied: monotonic~=1.5 in c:\users\ehabh\anaconda3\lib\site-packages (from segment-analytics-python==2.2.3->pygwalker) (1.6)
# Requirement already satisfied: python-dateutil~=2.2 in c:\users\ehabh\anaconda3\lib\site-packages (from segment-analytics-python==2.2.3->pygwalker) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipywidgets->pygwalker) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\ehabh\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\ehabh\anaconda3\lib\site-packages (from ipywidgets->pygwalker) (3.0.13)
# Requirement already satisfied: decorator in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (0.6.3)
# Requirement already satisfied: colorama in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from ipython->pygwalker) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ehabh\anaconda3\lib\site-packages (from requests->pygwalker) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ehabh\anaconda3\lib\site-packages (from requests->pygwalker) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ehabh\anaconda3\lib\site-packages (from requests->pygwalker) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ehabh\anaconda3\lib\site-packages (from requests->pygwalker) (2024.8.30)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\ehabh\anaconda3\lib\site-packages (from anywidget->pygwalker) (0.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ehabh\anaconda3\lib\site-packages (from jinja2->pygwalker) (2.1.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ehabh\anaconda3\lib\site-packages (from pandas->pygwalker) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ehabh\anaconda3\lib\site-packages (from pydantic->pygwalker) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\ehabh\anaconda3\lib\site-packages (from pydantic->pygwalker) (2.14.6)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ehabh\anaconda3\lib\site-packages (from sqlalchemy->pygwalker) (3.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython->pygwalker) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->pygwalker) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\ehabh\anaconda3\lib\site-packages (from python-dateutil~=2.2->segment-analytics-python==2.2.3->pygwalker) (1.16.0)
# Requirement already satisfied: importlib-resources>=5.10 in c:\users\ehabh\anaconda3\lib\site-packages (from wasmtime>=12.0.0->gw-dsl-parser==0.1.49.1->pygwalker) (6.4.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from stack-data->ipython->pygwalker) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from stack-data->ipython->pygwalker) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ehabh\appdata\roaming\python\python312\site-packages (from stack-data->ipython->pygwalker) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **2. Import Libraries**

# %%
import pandas as pd         # Data manipulation
import pygwalker as pyg      # Interactive visualization

# %% [markdown]
# ### **3. Load Your Dataset**
#
# Load data from a CSV file or create your own DataFrame:

# %%
# Example: Creating a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 29],
    'Salary': [50000, 60000, 70000, 80000, 52000],
    'Department': ['HR', 'IT', 'Finance', 'HR', 'IT']
}
df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         HR
# 1      Bob   30   60000         IT
# 2  Charlie   35   70000    Finance
# 3    David   40   80000         HR
# 4      Eva   29   52000         IT

# %% [markdown]
# ### **4. Start PyGWalker**
#
# Create an interactive visualization interface:

# %%
gwalker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000627419b36e7a9Ly0zfp3sv1coEi4H" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000627419b36e7a9Ly0zfp3sv1coEi4H") {
#             var iframe = document.getElementById("gwalker-000627419b36e7a9Ly0zfp3sv1coEi4H");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %% [markdown]
# ### **Custom Themes**
#
# Enhance the appearance of your visualizations:

# %%
pyg.walk(df, vegaTheme='vega')
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000627419b3abb3e72R3gJcqayKObnmZ" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000627419b3abb3e72R3gJcqayKObnmZ") {
#             var iframe = document.getElementById("gwalker-000627419b3abb3e72R3gJcqayKObnmZ");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %% [markdown]
# #### **That's it. Now you have an interactive UI to analyze and visualize data with simple drag-and-drop operations.**

# %% [markdown]
# ![Screenshot 2024-11-19 123437.png](attachment:b6d2adff-e504-4479-9cbc-45d52243728d.png)

# %% [markdown]
# ![image.png](attachment:12c8517f-5438-470e-95a1-a2b9986fd577.png)

# %% [markdown]
# #### **To compare different measures, you can create a concat view by adding more than one measure into rows/columns.**

# %% [markdown]
# ![image.png](attachment:2e4f81af-4eb7-49e9-a640-5da68609da8c.png)
